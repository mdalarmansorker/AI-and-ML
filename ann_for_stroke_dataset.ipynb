# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
fid = drive.ListFile({'q':"title='stroke.zip'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('stroke.zip')
f.keys()
# !unzip stroke.zip
# Out:
# Archive:  stroke.zip
#   inflating: healthcare-dataset-stroke-data.csv

# %%
data = pd.read_csv('healthcare-dataset-stroke-data.csv')
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
data.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
mean_bmi = data['bmi'].mean()
data['bmi'] = data['bmi'].fillna(mean_bmi)
data.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# 1     Self-employed          Rural             202.21  28.893237
# 2           Private          Rural             105.92  32.500000
# 3           Private          Urban             171.23  34.400000
# 4     Self-employed          Rural             174.12  24.000000
# ...             ...            ...                ...        ...
# 5105        Private          Urban              83.75  28.893237
# 5106  Self-employed          Urban             125.20  40.000000
# 5107  Self-employed          Rural              82.99  30.600000
# 5108        Private          Rural             166.29  25.600000
# 5109       Govt_job          Urban              85.28  26.200000
#
#        smoking_status  stroke
# 0     formerly smoked       1
# 1        never smoked       1
# 2        never smoked       1
# 3              smokes       1
# 4        never smoked       1
# ...               ...     ...
# 5105     never smoked       0
# 5106     never smoked       0
# 5107     never smoked       0
# 5108  formerly smoked       0
# 5109          Unknown       0
#
# [5110 rows x 12 columns]

# %%
# defining feature matrix(X) and response vector(y) 
X = data.iloc[:,1:-1]
X
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level        bmi   smoking_status
# 0             Urban             228.69  36.600000  formerly smoked
# 1             Rural             202.21  28.893237     never smoked
# 2             Rural             105.92  32.500000     never smoked
# 3             Urban             171.23  34.400000           smokes
# 4             Rural             174.12  24.000000     never smoked
# ...             ...                ...        ...              ...
# 5105          Urban              83.75  28.893237     never smoked
# 5106          Urban             125.20  40.000000     never smoked
# 5107          Rural              82.99  30.600000     never smoked
# 5108          Rural             166.29  25.600000  formerly smoked
# 5109          Urban              85.28  26.200000          Unknown
#
# [5110 rows x 10 columns]

# %%
y = data.iloc[:,-1:]
y
# Out:
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import OneHotEncoder
#convert categorical to numeric
labelencoder_X=LabelEncoder()
z = X.iloc[:,0]
X.iloc[:,0] = labelencoder_X.fit_transform(z.values.ravel())
X
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0          1  67.0             0              1          Yes        Private
# 1          0  61.0             0              0          Yes  Self-employed
# 2          1  80.0             0              1          Yes        Private
# 3          0  49.0             0              0          Yes        Private
# 4          0  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105       0  80.0             1              0          Yes        Private
# 5106       0  81.0             0              0          Yes  Self-employed
# 5107       0  35.0             0              0          Yes  Self-employed
# 5108       1  51.0             0              0          Yes        Private
# 5109       0  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level        bmi   smoking_status
# 0             Urban             228.69  36.600000  formerly smoked
# 1             Rural             202.21  28.893237     never smoked
# 2             Rural             105.92  32.500000     never smoked
# 3             Urban             171.23  34.400000           smokes
# 4             Rural             174.12  24.000000     never smoked
# ...             ...                ...        ...              ...
# 5105          Urban              83.75  28.893237     never smoked
# 5106          Urban             125.20  40.000000     never smoked
# 5107          Rural              82.99  30.600000     never smoked
# 5108          Rural             166.29  25.600000  formerly smoked
# 5109          Urban              85.28  26.200000          Unknown
#
# [5110 rows x 10 columns]

# %%
#convert categorical to numeric
labelencoder_X=LabelEncoder()
z = X.iloc[:,4]
X.iloc[:,4] = labelencoder_X.fit_transform(z.values.ravel())
X
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#      Residence_type  avg_glucose_level        bmi   smoking_status
# 0             Urban             228.69  36.600000  formerly smoked
# 1             Rural             202.21  28.893237     never smoked
# 2             Rural             105.92  32.500000     never smoked
# 3             Urban             171.23  34.400000           smokes
# 4             Rural             174.12  24.000000     never smoked
# ...             ...                ...        ...              ...
# 5105          Urban              83.75  28.893237     never smoked
# 5106          Urban             125.20  40.000000     never smoked
# 5107          Rural              82.99  30.600000     never smoked
# 5108          Rural             166.29  25.600000  formerly smoked
# 5109          Urban              85.28  26.200000          Unknown
#
# [5110 rows x 10 columns]

# %%
#convert categorical to numeric
labelencoder_X=LabelEncoder()
z = X.iloc[:,5]
X.iloc[:,5] = labelencoder_X.fit_transform(z.values.ravel())
X
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#      Residence_type  avg_glucose_level        bmi   smoking_status
# 0             Urban             228.69  36.600000  formerly smoked
# 1             Rural             202.21  28.893237     never smoked
# 2             Rural             105.92  32.500000     never smoked
# 3             Urban             171.23  34.400000           smokes
# 4             Rural             174.12  24.000000     never smoked
# ...             ...                ...        ...              ...
# 5105          Urban              83.75  28.893237     never smoked
# 5106          Urban             125.20  40.000000     never smoked
# 5107          Rural              82.99  30.600000     never smoked
# 5108          Rural             166.29  25.600000  formerly smoked
# 5109          Urban              85.28  26.200000          Unknown
#
# [5110 rows x 10 columns]

# %%
#convert categorical to numeric
labelencoder_X=LabelEncoder()
z = X.iloc[:,6]
X.iloc[:,6] = labelencoder_X.fit_transform(z.values.ravel())
X
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi   smoking_status
# 0                  1             228.69  36.600000  formerly smoked
# 1                  0             202.21  28.893237     never smoked
# 2                  0             105.92  32.500000     never smoked
# 3                  1             171.23  34.400000           smokes
# 4                  0             174.12  24.000000     never smoked
# ...              ...                ...        ...              ...
# 5105               1              83.75  28.893237     never smoked
# 5106               1             125.20  40.000000     never smoked
# 5107               0              82.99  30.600000     never smoked
# 5108               0             166.29  25.600000  formerly smoked
# 5109               1              85.28  26.200000          Unknown
#
# [5110 rows x 10 columns]

# %%
#convert categorical to numeric
labelencoder_X=LabelEncoder()
z = X.iloc[:,-1]
X.iloc[:,-1] = labelencoder_X.fit_transform(z.values.ravel())
X
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi  smoking_status
# 0                  1             228.69  36.600000               1
# 1                  0             202.21  28.893237               2
# 2                  0             105.92  32.500000               2
# 3                  1             171.23  34.400000               3
# 4                  0             174.12  24.000000               2
# ...              ...                ...        ...             ...
# 5105               1              83.75  28.893237               2
# 5106               1             125.20  40.000000               2
# 5107               0              82.99  30.600000               2
# 5108               0             166.29  25.600000               1
# 5109               1              85.28  26.200000               0
#
# [5110 rows x 10 columns]

# %%
#z score normalization
scaller = StandardScaler()
X = scaller.fit_transform(X)
X
# Out:
# array([[ 1.18807255e+00,  1.05143428e+00, -3.28601864e-01, ...,
#          2.70637544e+00,  1.00123401e+00, -3.51780710e-01],
#        [-8.40343999e-01,  7.86070073e-01, -3.28601864e-01, ...,
#          2.12155854e+00,  4.39307442e-16,  5.81552327e-01],
#        [ 1.18807255e+00,  1.62639008e+00, -3.28601864e-01, ...,
#         -5.02830130e-03,  4.68577254e-01,  5.81552327e-01],
#        ...,
#        [-8.40343999e-01, -3.63841511e-01, -3.28601864e-01, ...,
#         -5.11442636e-01,  2.21736316e-01,  5.81552327e-01],
#        [ 1.18807255e+00,  3.43796387e-01, -3.28601864e-01, ...,
#          1.32825706e+00, -4.27845098e-01, -3.51780710e-01],
#        [-8.40343999e-01,  3.42048064e-02, -3.28601864e-01, ...,
#         -4.60867458e-01, -3.49895329e-01, -1.28511375e+00]])

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(y)
y = encoder.transform(y)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
# splitting X and y into training and testing sets  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from keras.utils import np_utils
# convert integers to dummy variables (i.e. one hot encoded)
y_train = np_utils.to_categorical(y_train)

# %%
# define the keras model
model = Sequential()
model.add(Dense(6, input_dim=10, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='softmax'))

# %%
# compile the keras model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X_train, y_train, epochs=100, batch_size=30)

acc = model.evaluate(X_train, y_train)
print("Loss:", acc[0], " Accuracy:", acc[1])
# Out:
# Epoch 1/100
# 137/137 [==============================] - 1s 1ms/step - loss: 0.4435 - accuracy: 0.8828
# Epoch 2/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.2312 - accuracy: 0.9538
# Epoch 3/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1916 - accuracy: 0.9538
# Epoch 4/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1786 - accuracy: 0.9538
# Epoch 5/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1715 - accuracy: 0.9538
# Epoch 6/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1665 - accuracy: 0.9538
# Epoch 7/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1632 - accuracy: 0.9538
# Epoch 8/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1608 - accuracy: 0.9538
# Epoch 9/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1591 - accuracy: 0.9538
# Epoch 10/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1576 - accuracy: 0.9538
# Epoch 11/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1564 - accuracy: 0.9538
# Epoch 12/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1548 - accuracy: 0.9538
# Epoch 13/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1537 - accuracy: 0.9538
# Epoch 14/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1526 - accuracy: 0.9538
# Epoch 15/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1521 - accuracy: 0.9538
# Epoch 16/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1518 - accuracy: 0.9538
# Epoch 17/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1510 - accuracy: 0.9538
# Epoch 18/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1505 - accuracy: 0.9538
# Epoch 19/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1503 - accuracy: 0.9538
# Epoch 20/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1501 - accuracy: 0.9538
# Epoch 21/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1497 - accuracy: 0.9538
# Epoch 22/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1499 - accuracy: 0.9538
# Epoch 23/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1494 - accuracy: 0.9538
# Epoch 24/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1489 - accuracy: 0.9538
# Epoch 25/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1489 - accuracy: 0.9538
# Epoch 26/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1486 - accuracy: 0.9538
# Epoch 27/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1484 - accuracy: 0.9538
# Epoch 28/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1481 - accuracy: 0.9538
# Epoch 29/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1481 - accuracy: 0.9538
# Epoch 30/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1480 - accuracy: 0.9538
# Epoch 31/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1480 - accuracy: 0.9538
# Epoch 32/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1478 - accuracy: 0.9538
# Epoch 33/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1477 - accuracy: 0.9538
# Epoch 34/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1477 - accuracy: 0.9538
# Epoch 35/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1476 - accuracy: 0.9538
# Epoch 36/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1473 - accuracy: 0.9538
# Epoch 37/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1472 - accuracy: 0.9538
# Epoch 38/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.1473 - accuracy: 0.9538
# Epoch 39/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1469 - accuracy: 0.9538
# Epoch 40/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1470 - accuracy: 0.9538
# Epoch 41/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1467 - accuracy: 0.9538
# Epoch 42/100
# 137/137 [==============================] - 0s 3ms/step - loss: 0.1467 - accuracy: 0.9538
# Epoch 43/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1465 - accuracy: 0.9538
# Epoch 44/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.1465 - accuracy: 0.9538
# Epoch 45/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.1462 - accuracy: 0.9538
# Epoch 46/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1463 - accuracy: 0.9538
# Epoch 47/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1461 - accuracy: 0.9538
# Epoch 48/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1461 - accuracy: 0.9538
# Epoch 49/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1461 - accuracy: 0.9538
# Epoch 50/100
# 137/137 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.9538
# Epoch 51/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1459 - accuracy: 0.9538
# Epoch 52/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1459 - accuracy: 0.9538
# Epoch 53/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1456 - accuracy: 0.9538
# Epoch 54/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1455 - accuracy: 0.9538
# Epoch 55/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1454 - accuracy: 0.9538
# Epoch 56/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1454 - accuracy: 0.9538
# Epoch 57/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1450 - accuracy: 0.9538
# Epoch 64/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1449 - accuracy: 0.9538
# Epoch 65/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1446 - accuracy: 0.9538
# Epoch 66/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1445 - accuracy: 0.9538
# Epoch 67/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1444 - accuracy: 0.9538
# Epoch 68/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1448 - accuracy: 0.9538
# Epoch 69/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1447 - accuracy: 0.9538
# Epoch 70/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1444 - accuracy: 0.9538
# Epoch 71/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1444 - accuracy: 0.9538
# Epoch 72/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1447 - accuracy: 0.9538
# Epoch 73/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1445 - accuracy: 0.9538
# Epoch 74/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1443 - accuracy: 0.9538
# Epoch 75/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1445 - accuracy: 0.9538
# Epoch 76/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1443 - accuracy: 0.9538
# Epoch 77/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1443 - accuracy: 0.9538
# Epoch 78/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1442 - accuracy: 0.9538
# Epoch 79/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1444 - accuracy: 0.9538
# Epoch 80/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1442 - accuracy: 0.9538
# Epoch 81/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1443 - accuracy: 0.9538
# Epoch 82/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1443 - accuracy: 0.9538
# Epoch 83/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1441 - accuracy: 0.9538
# Epoch 84/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1441 - accuracy: 0.9538
# Epoch 85/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1441 - accuracy: 0.9538
# Epoch 86/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1440 - accuracy: 0.9538
# Epoch 87/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1443 - accuracy: 0.9538
# Epoch 88/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1440 - accuracy: 0.9538
# Epoch 89/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1440 - accuracy: 0.9538
# Epoch 90/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1440 - accuracy: 0.9538
# Epoch 91/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1444 - accuracy: 0.9538
# Epoch 92/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1440 - accuracy: 0.9538
# Epoch 93/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1440 - accuracy: 0.9538
# Epoch 94/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1440 - accuracy: 0.9538
# Epoch 95/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1440 - accuracy: 0.9538
# Epoch 96/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1440 - accuracy: 0.9538
# Epoch 97/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1440 - accuracy: 0.9538
# Epoch 98/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1439 - accuracy: 0.9538
# Epoch 99/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1438 - accuracy: 0.9538
# Epoch 100/100
# 137/137 [==============================] - 0s 1ms/step - loss: 0.1438 - accuracy: 0.9538
# 128/128 [==============================] - 0s 909us/step - loss: 0.1432 - accuracy: 0.9538
# Loss: 0.14315065741539001  Accuracy: 0.9537671208381653

# %%
# get user input
gender = input("Enter gender (0 for female, 1 for male, 2 for other): ")
age = input("Enter age: ")
hypertension = input("Do you have hypertension? (0 for no, 1 for yes): ")
heart_disease = input("Do you have heart disease? (0 for no, 1 for yes): ")
ever_married = input("Are you married? (0 for no, 1 for yes): ")
work_type = input("Enter work type (0 for children, 1 for Govt_job, 2 for Never_worked, 3 for Private, 4 for Self-employed): ")
Residence_type = input("Enter residence type (0 for rural, 1 for urban): ")
avg_glucose_level = input("Enter average glucose level: ")
bmi = input("Enter bmi: ")

smoking_status = input("Enter smoking status (0 for formerly smoked, 1 for never smoked, 2 for smokes, 3 for unknown): ")

# make predictions on the user input
input_data = np.array([[gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level,bmi, smoking_status]])
input_data = scaller.transform(input_data)
pred = model.predict(input_data)
pred_y = pred
# Out:
# Enter gender (0 for female, 1 for male, 2 for other): 1
# Enter age: 79
# Do you have hypertension? (0 for no, 1 for yes): 0
# Do you have heart disease? (0 for no, 1 for yes): 1
# Are you married? (0 for no, 1 for yes): 1
# Enter work type (0 for children, 1 for Govt_job, 2 for Never_worked, 3 for Private, 4 for Self-employed): 3
# Enter residence type (0 for rural, 1 for urban): 1
# Enter average glucose level: 57.8
# Enter bmi: 22
# Enter smoking status (0 for formerly smoked, 1 for never smoked, 2 for smokes, 3 for unknown): 0
# 1/1 [==============================] - 0s 17ms/step

# %%
if pred_y[0][1] > pred_y[0][0]:
    print("The user is predicted to have a stroke.")
else:
    print("The user is predicted to not have a stroke.")
# Out:
# The user is predicted to not have a stroke.
