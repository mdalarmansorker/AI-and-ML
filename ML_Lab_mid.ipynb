# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('healthcare-dataset-stroke-data.csv')
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
# Create a box plot to visualize the distribution of each column in the dataset
sns.boxplot(data=data, orient="p")
# Out:
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
data.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
mean_bmi = data['bmi'].mean()
data['bmi'] = data['bmi'].fillna(mean_bmi)
data.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# 1     Self-employed          Rural             202.21  28.893237
# 2           Private          Rural             105.92  32.500000
# 3           Private          Urban             171.23  34.400000
# 4     Self-employed          Rural             174.12  24.000000
# ...             ...            ...                ...        ...
# 5105        Private          Urban              83.75  28.893237
# 5106  Self-employed          Urban             125.20  40.000000
# 5107  Self-employed          Rural              82.99  30.600000
# 5108        Private          Rural             166.29  25.600000
# 5109       Govt_job          Urban              85.28  26.200000
#
#        smoking_status  stroke
# 0     formerly smoked       1
# 1        never smoked       1
# 2        never smoked       1
# 3              smokes       1
# 4        never smoked       1
# ...               ...     ...
# 5105     never smoked       0
# 5106     never smoked       0
# 5107     never smoked       0
# 5108  formerly smoked       0
# 5109          Unknown       0
#
# [5110 rows x 12 columns]

# %%
# defining feature matrix(X) and response vector(y) 
X = data.iloc[:,1:-1]
X
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level        bmi   smoking_status
# 0             Urban             228.69  36.600000  formerly smoked
# 1             Rural             202.21  28.893237     never smoked
# 2             Rural             105.92  32.500000     never smoked
# 3             Urban             171.23  34.400000           smokes
# 4             Rural             174.12  24.000000     never smoked
# ...             ...                ...        ...              ...
# 5105          Urban              83.75  28.893237     never smoked
# 5106          Urban             125.20  40.000000     never smoked
# 5107          Rural              82.99  30.600000     never smoked
# 5108          Rural             166.29  25.600000  formerly smoked
# 5109          Urban              85.28  26.200000          Unknown
#
# [5110 rows x 10 columns]

# %%
y = data.iloc[:,-1:]
y
# Out:
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import OneHotEncoder
#convert categorical to numeric
labelencoder_X=LabelEncoder()
z = X.iloc[:,0]
X.iloc[:,0] = labelencoder_X.fit_transform(z.values.ravel())
X
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0          1  67.0             0              1          Yes        Private
# 1          0  61.0             0              0          Yes  Self-employed
# 2          1  80.0             0              1          Yes        Private
# 3          0  49.0             0              0          Yes        Private
# 4          0  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105       0  80.0             1              0          Yes        Private
# 5106       0  81.0             0              0          Yes  Self-employed
# 5107       0  35.0             0              0          Yes  Self-employed
# 5108       1  51.0             0              0          Yes        Private
# 5109       0  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level        bmi   smoking_status
# 0             Urban             228.69  36.600000  formerly smoked
# 1             Rural             202.21  28.893237     never smoked
# 2             Rural             105.92  32.500000     never smoked
# 3             Urban             171.23  34.400000           smokes
# 4             Rural             174.12  24.000000     never smoked
# ...             ...                ...        ...              ...
# 5105          Urban              83.75  28.893237     never smoked
# 5106          Urban             125.20  40.000000     never smoked
# 5107          Rural              82.99  30.600000     never smoked
# 5108          Rural             166.29  25.600000  formerly smoked
# 5109          Urban              85.28  26.200000          Unknown
#
# [5110 rows x 10 columns]

# %%
#convert categorical to numeric
labelencoder_X=LabelEncoder()
z = X.iloc[:,4]
X.iloc[:,4] = labelencoder_X.fit_transform(z.values.ravel())
X
# Out:
#       gender   age  hypertension  heart_disease  ever_married      work_type  \
# 0          1  67.0             0              1             1        Private
# 1          0  61.0             0              0             1  Self-employed
# 2          1  80.0             0              1             1        Private
# 3          0  49.0             0              0             1        Private
# 4          0  79.0             1              0             1  Self-employed
# ...      ...   ...           ...            ...           ...            ...
# 5105       0  80.0             1              0             1        Private
# 5106       0  81.0             0              0             1  Self-employed
# 5107       0  35.0             0              0             1  Self-employed
# 5108       1  51.0             0              0             1        Private
# 5109       0  44.0             0              0             1       Govt_job
#
#      Residence_type  avg_glucose_level        bmi   smoking_status
# 0             Urban             228.69  36.600000  formerly smoked
# 1             Rural             202.21  28.893237     never smoked
# 2             Rural             105.92  32.500000     never smoked
# 3             Urban             171.23  34.400000           smokes
# 4             Rural             174.12  24.000000     never smoked
# ...             ...                ...        ...              ...
# 5105          Urban              83.75  28.893237     never smoked
# 5106          Urban             125.20  40.000000     never smoked
# 5107          Rural              82.99  30.600000     never smoked
# 5108          Rural             166.29  25.600000  formerly smoked
# 5109          Urban              85.28  26.200000          Unknown
#
# [5110 rows x 10 columns]

# %%
#convert categorical to numeric
labelencoder_X=LabelEncoder()
z = X.iloc[:,5]
X.iloc[:,5] = labelencoder_X.fit_transform(z.values.ravel())
X
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#      Residence_type  avg_glucose_level        bmi   smoking_status
# 0             Urban             228.69  36.600000  formerly smoked
# 1             Rural             202.21  28.893237     never smoked
# 2             Rural             105.92  32.500000     never smoked
# 3             Urban             171.23  34.400000           smokes
# 4             Rural             174.12  24.000000     never smoked
# ...             ...                ...        ...              ...
# 5105          Urban              83.75  28.893237     never smoked
# 5106          Urban             125.20  40.000000     never smoked
# 5107          Rural              82.99  30.600000     never smoked
# 5108          Rural             166.29  25.600000  formerly smoked
# 5109          Urban              85.28  26.200000          Unknown
#
# [5110 rows x 10 columns]

# %%
#convert categorical to numeric
labelencoder_X=LabelEncoder()
z = X.iloc[:,6]
X.iloc[:,6] = labelencoder_X.fit_transform(z.values.ravel())
X
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi   smoking_status
# 0                  1             228.69  36.600000  formerly smoked
# 1                  0             202.21  28.893237     never smoked
# 2                  0             105.92  32.500000     never smoked
# 3                  1             171.23  34.400000           smokes
# 4                  0             174.12  24.000000     never smoked
# ...              ...                ...        ...              ...
# 5105               1              83.75  28.893237     never smoked
# 5106               1             125.20  40.000000     never smoked
# 5107               0              82.99  30.600000     never smoked
# 5108               0             166.29  25.600000  formerly smoked
# 5109               1              85.28  26.200000          Unknown
#
# [5110 rows x 10 columns]

# %%
#convert categorical to numeric
labelencoder_X=LabelEncoder()
z = X.iloc[:,-1]
X.iloc[:,-1] = labelencoder_X.fit_transform(z.values.ravel())
X
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi  smoking_status
# 0                  1             228.69  36.600000               1
# 1                  0             202.21  28.893237               2
# 2                  0             105.92  32.500000               2
# 3                  1             171.23  34.400000               3
# 4                  0             174.12  24.000000               2
# ...              ...                ...        ...             ...
# 5105               1              83.75  28.893237               2
# 5106               1             125.20  40.000000               2
# 5107               0              82.99  30.600000               2
# 5108               0             166.29  25.600000               1
# 5109               1              85.28  26.200000               0
#
# [5110 rows x 10 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# Create a MinMaxScaler object
scaler = MinMaxScaler()

# Fit the scaler to the feature matrix X
scaler.fit(X)

# Transform the feature matrix X using the fitted scaler
X = scaler.transform(X)

# %%
X
# Out:
# array([[0.5       , 0.81689453, 0.        , ..., 0.80126489, 0.30126002,
#         0.33333333],
#        [0.        , 0.74365234, 0.        , ..., 0.67902317, 0.21298095,
#         0.66666667],
#        [0.5       , 0.97558594, 0.        , ..., 0.23451205, 0.25429553,
#         0.66666667],
#        ...,
#        [0.        , 0.42626953, 0.        , ..., 0.12865848, 0.2325315 ,
#         0.66666667],
#        [0.5       , 0.62158203, 0.        , ..., 0.51320284, 0.17525773,
#         0.33333333],
#        [0.        , 0.53613281, 0.        , ..., 0.13922999, 0.18213058,
#         0.        ]])

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(y)
y = encoder.transform(y)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
# splitting X and y into training and testing sets  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# %%
from keras.utils import np_utils
# convert integers to dummy variables (i.e. one hot encoded)
y_train = np_utils.to_categorical(y_train)

# %%
# define the keras model
model = Sequential()
model.add(Dense(6, input_dim=10, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='softmax'))

# %%
# compile the keras model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X_train, y_train, epochs=100, batch_size=30)

acc = model.evaluate(X_train, y_train)
print("Loss:", acc[0], " Accuracy:", acc[1])
# Out:
# Epoch 1/100
# 103/103 [==============================] - 1s 2ms/step - loss: 0.6154 - accuracy: 0.7365
# Epoch 2/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.2914 - accuracy: 0.9534
# Epoch 3/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.2198 - accuracy: 0.9534
# Epoch 4/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.2105 - accuracy: 0.9534
# Epoch 5/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.2039 - accuracy: 0.9534
# Epoch 6/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1972 - accuracy: 0.9534
# Epoch 7/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1914 - accuracy: 0.9534
# Epoch 8/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1858 - accuracy: 0.9534
# Epoch 9/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1816 - accuracy: 0.9534
# Epoch 10/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1783 - accuracy: 0.9534
# Epoch 11/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1750 - accuracy: 0.9534
# Epoch 12/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1725 - accuracy: 0.9534
# Epoch 13/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1706 - accuracy: 0.9534
# Epoch 14/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1694 - accuracy: 0.9534
# Epoch 15/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1680 - accuracy: 0.9534
# Epoch 16/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1667 - accuracy: 0.9534
# Epoch 17/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1660 - accuracy: 0.9534
# Epoch 18/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1653 - accuracy: 0.9534
# Epoch 19/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1648 - accuracy: 0.9534
# Epoch 20/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1638 - accuracy: 0.9534
# Epoch 21/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1632 - accuracy: 0.9534
# Epoch 22/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1627 - accuracy: 0.9534
# Epoch 23/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1620 - accuracy: 0.9534
# Epoch 24/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1617 - accuracy: 0.9534
# Epoch 25/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1612 - accuracy: 0.9534
# Epoch 26/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1611 - accuracy: 0.9534
# Epoch 27/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1609 - accuracy: 0.9534
# Epoch 28/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1603 - accuracy: 0.9534
# Epoch 29/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1599 - accuracy: 0.9534
# Epoch 30/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1591 - accuracy: 0.9534
# Epoch 31/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1592 - accuracy: 0.9534
# Epoch 32/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1591 - accuracy: 0.9534
# Epoch 33/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1584 - accuracy: 0.9534
# Epoch 34/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1582 - accuracy: 0.9534
# Epoch 35/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1578 - accuracy: 0.9534
# Epoch 36/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1576 - accuracy: 0.9534
# Epoch 37/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1575 - accuracy: 0.9534
# Epoch 38/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1572 - accuracy: 0.9534
# Epoch 39/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1565 - accuracy: 0.9534
# Epoch 40/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1569 - accuracy: 0.9534
# Epoch 41/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1564 - accuracy: 0.9534
# Epoch 42/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1564 - accuracy: 0.9534
# Epoch 43/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1564 - accuracy: 0.9534
# Epoch 44/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1562 - accuracy: 0.9534
# Epoch 45/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1562 - accuracy: 0.9534
# Epoch 46/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1565 - accuracy: 0.9534
# Epoch 47/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1561 - accuracy: 0.9534
# Epoch 48/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1561 - accuracy: 0.9534
# Epoch 49/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1558 - accuracy: 0.9534
# Epoch 50/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1559 - accuracy: 0.9534
# Epoch 51/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1557 - accuracy: 0.9534
# Epoch 52/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1555 - accuracy: 0.9534
# Epoch 53/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1554 - accuracy: 0.9534
# Epoch 54/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1552 - accuracy: 0.9534
# Epoch 55/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1551 - accuracy: 0.9534
# Epoch 56/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1551 - accuracy: 0.9534
# Epoch 57/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1552 - accuracy: 0.9534
# Epoch 58/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1544 - accuracy: 0.9534
# Epoch 59/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1554 - accuracy: 0.9534
# Epoch 60/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1550 - accuracy: 0.9534
# Epoch 61/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1548 - accuracy: 0.9534
# Epoch 62/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1548 - accuracy: 0.9534
# Epoch 63/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1545 - accuracy: 0.9534
# Epoch 64/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1545 - accuracy: 0.9534
# Epoch 65/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1545 - accuracy: 0.9534
# Epoch 66/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1544 - accuracy: 0.9534
# Epoch 67/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1541 - accuracy: 0.9534
# Epoch 68/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1546 - accuracy: 0.9534
# Epoch 69/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1541 - accuracy: 0.9534
# Epoch 70/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1543 - accuracy: 0.9534
# Epoch 71/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1542 - accuracy: 0.9534
# Epoch 72/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.9534
# Epoch 73/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1544 - accuracy: 0.9534
# Epoch 74/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1538 - accuracy: 0.9534
# Epoch 75/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1541 - accuracy: 0.9534
# Epoch 76/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1546 - accuracy: 0.9534
# Epoch 77/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1537 - accuracy: 0.9534
# Epoch 78/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1539 - accuracy: 0.9534
# Epoch 79/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1541 - accuracy: 0.9534
# Epoch 80/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1536 - accuracy: 0.9534
# Epoch 81/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.9534
# Epoch 82/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1545 - accuracy: 0.9534
# Epoch 83/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1533 - accuracy: 0.9534
# Epoch 84/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1544 - accuracy: 0.9534
# Epoch 85/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1537 - accuracy: 0.9534
# Epoch 86/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1544 - accuracy: 0.9534
# Epoch 87/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1536 - accuracy: 0.9534
# Epoch 88/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1534 - accuracy: 0.9534
# Epoch 89/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1532 - accuracy: 0.9534
# Epoch 90/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1536 - accuracy: 0.9534
# Epoch 91/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1534 - accuracy: 0.9534
# Epoch 92/100
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1532 - accuracy: 0.9534
# Epoch 93/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1533 - accuracy: 0.9534
# Epoch 94/100
# 103/103 [==============================] - 0s 4ms/step - loss: 0.1532 - accuracy: 0.9534
# Epoch 95/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1534 - accuracy: 0.9534
# Epoch 96/100
# 103/103 [==============================] - 0s 4ms/step - loss: 0.1533 - accuracy: 0.9534
# Epoch 97/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1530 - accuracy: 0.9534
# Epoch 98/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1534 - accuracy: 0.9534
# Epoch 99/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1537 - accuracy: 0.9534
# Epoch 100/100
# 103/103 [==============================] - 0s 3ms/step - loss: 0.1532 - accuracy: 0.9534
# 96/96 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.9534
# Loss: 0.15243521332740784  Accuracy: 0.9533594250679016
